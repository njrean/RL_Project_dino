# %%
import function
import Dinogame_Env
import DinoAgent
import Dinogame_State
import variable_setup
import Model
import visualize

import importlib
importlib.reload(function)
importlib.reload(Dinogame_Env)
importlib.reload(variable_setup)
importlib.reload(DinoAgent)
importlib.reload(Dinogame_State)
importlib.reload(Model)
importlib.reload(visualize)

from function import *
from Dinogame_Env import *
from DinoAgent import *
from Dinogame_State import *
from variable_setup import *
from Model import *
from visualize import *

import time

import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create object

# %%
# dino_env = DinoGame_Env()
# dino = DinoAgent(dino_env)
# game_state = Dinogame_State(dino, dino_env)
model = buildmodel()
# Out:
# Now we build the model
# -----Loaded model-----

# %% [markdown]
# ## Train Model

# %%
# train_model(model, game_state)

# %% [markdown]
# ## Run trained model

# %%
# run_train_model(model, game_state, EPSILON=0.1)

# %% [markdown]
# ## Analyze State-action value

# %%
# analyze_value(1, model)

# %% [markdown]
# ## Visualize result

# %%
score_path = "./save_buffer/ver4/scores_df.csv"
loss_path = "./save_buffer/ver4/loss_df.csv"
plot_graph(score_path)
plot_graph(loss_path, mode='loss')
# Out:
# 86.0

# %%
score_path = "./save_buffer/ver5/scores_df.csv"
loss_path = "./save_buffer/ver5/loss_df.csv"

plot_graph(score_path)
plot_graph(loss_path, mode='loss', batch_size=32)
# Out:
# 95.0

# %%
score_path = "./save_buffer/ver6/scores_df.csv"
loss_path = "./save_buffer/ver6/loss_df.csv"

plot_graph(score_path)
plot_graph(loss_path, mode='loss', batch_size=32)
# Out:
# 130.0
